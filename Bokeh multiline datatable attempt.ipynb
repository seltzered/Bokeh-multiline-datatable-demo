# %%
import bokeh
from bokeh.plotting import figure, output_notebook, show, vplot
from bokeh.io import output_file, show, vform
from bokeh.models import ColumnDataSource
from bokeh.models.widgets import DataTable, StringFormatter, TableColumn

output_notebook()


table_data = ColumnDataSource(dict(strings=['[ -1.23456, \n \
7.89012, \n \
3.456789 \n \
 ]', \
   '[ -1.23456, \n \
7.89012, \n \
3.456789 \n \
 ]'] 
))
columns = [TableColumn(field="strings", title="Strings", formatter=StringFormatter(text_color='#BB0000')) ]
tableplot = DataTable(source=table_data, columns=columns)
    
show(vform(tableplot))
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b1c19eba-e316-457f-a42c-44703028b4ca">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="f88f9227-eae4-4523-9ad4-0bfe7301e4d5"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f88f9227-eae4-4523-9ad4-0bfe7301e4d5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f88f9227-eae4-4523-9ad4-0bfe7301e4d5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c362d920-6a68-4d13-b90b-c08887b4191f":{"roots":{"references":[{"attributes":{},"id":"8666b1c3-ccfa-463f-9833-f6804988a7a7","type":"StringEditor"},{"attributes":{"children":[{"id":"064d8030-5426-476b-8191-27b662fcdc8b","type":"DataTable"}]},"id":"6a486e2e-4633-4643-bf0d-0c187266949d","type":"VBoxForm"},{"attributes":{"children":[{"id":"bdbe1e4e-3d4a-455e-a45c-d7b124247b81","type":"DataTable"}]},"id":"a2804edb-6a66-454d-9d48-9227cfda0c60","type":"VBoxForm"},{"attributes":{"children":[{"id":"e9371ac2-e903-4c0c-aa97-58182fff377b","type":"DataTable"}]},"id":"657d47c0-d2d5-4fd7-9351-0dad0b9eca93","type":"VBoxForm"},{"attributes":{},"id":"7c7d5607-863f-4c4b-b557-49a597649012","type":"StringEditor"},{"attributes":{"editor":{"id":"b3929e2b-d39b-47db-8ee2-3479e58d52a0","type":"StringEditor"},"field":"strings","formatter":{"id":"0fb296cb-5b25-4a8c-802e-1dcfdb9aff32","type":"StringFormatter"},"title":"Strings"},"id":"d19c0207-61c0-42e8-967f-d56a558e1cd3","type":"TableColumn"},{"attributes":{"callback":null,"column_names":["strings"],"data":{"strings":["[ -1.23456, \n 7.89012, \n 3.456789 \n  ]","[ -1.23456, \n 7.89012, \n 3.456789 \n  ]"]}},"id":"d8c392b0-0ad7-4b76-bf7d-e5909b427f82","type":"ColumnDataSource"},{"attributes":{"editor":{"id":"1c18a1cc-3ec2-4b0b-bcd3-4ce3c238d8d7","type":"StringEditor"},"field":"strings","formatter":{"id":"c843f13a-9d3c-4df8-9d87-7ed106fa0ea2","type":"StringFormatter"},"title":"Strings"},"id":"b779413d-0585-4de0-a45f-eecece706c47","type":"TableColumn"},{"attributes":{"children":[{"id":"e134f7c4-f069-4669-bd17-228b6ea52a3f","type":"DataTable"}]},"id":"5fa5dd97-de47-405f-b3e4-70a15c20f1da","type":"VBoxForm"},{"attributes":{"columns":[{"id":"71c5b36c-fd8f-46f1-8865-53ec1b5c11e3","type":"TableColumn"}],"source":{"id":"c2325e3c-ed60-4278-9b68-3d72a23152c4","type":"ColumnDataSource"}},"id":"2b1a8cf6-0a02-4754-a297-d1fe43962f68","type":"DataTable"},{"attributes":{"text_color":"#FF0000"},"id":"aa176389-4702-4132-b941-719b9f32899c","type":"StringFormatter"},{"attributes":{"text_color":"#FF0000"},"id":"0fb296cb-5b25-4a8c-802e-1dcfdb9aff32","type":"StringFormatter"},{"attributes":{"editor":{"id":"999eae17-862f-4b6d-bbec-acdf06971be0","type":"StringEditor"},"field":"strings","formatter":{"id":"4d388316-2fa1-4b12-ac54-3497b4aef3f9","type":"StringFormatter"},"title":"Strings"},"id":"71c5b36c-fd8f-46f1-8865-53ec1b5c11e3","type":"TableColumn"},{"attributes":{"callback":null,"column_names":["strings"],"data":{"strings":["[ -29.3744618351, \n 3.33621434705, \n 5.59740268769, \n  ]"]}},"id":"c2325e3c-ed60-4278-9b68-3d72a23152c4","type":"ColumnDataSource"},{"attributes":{},"id":"999eae17-862f-4b6d-bbec-acdf06971be0","type":"StringEditor"},{"attributes":{"callback":null,"column_names":["strings"],"data":{"strings":["[ -29.3744618351, \n 3.33621434705, \n 5.59740268769 \n  ]","[ -29.3744618351, \n 3.33621434705, \n 5.59740268769 \n  ]"]}},"id":"b1a504af-87bc-47b1-baae-502ff29c7149","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["strings"],"data":{"strings":["[ -1.23456, \n 7.89012, \n 3.456789 \n  ]","[ -1.23456, \n 7.89012, \n 3.456789 \n  ]"]}},"id":"626b9ae2-7ffb-4f05-8606-80881c27a3c6","type":"ColumnDataSource"},{"attributes":{"text_color":"#FF0000"},"id":"4d388316-2fa1-4b12-ac54-3497b4aef3f9","type":"StringFormatter"},{"attributes":{"columns":[{"id":"21f4d094-03f8-4a07-87b3-41cfd003b195","type":"TableColumn"}],"source":{"id":"23d98ce6-5c8c-4b52-bf3d-fd322784dbed","type":"ColumnDataSource"}},"id":"064d8030-5426-476b-8191-27b662fcdc8b","type":"DataTable"},{"attributes":{"columns":[{"id":"7baba5e7-22f4-45a4-8d72-c8aee01e96de","type":"TableColumn"}],"source":{"id":"b1a504af-87bc-47b1-baae-502ff29c7149","type":"ColumnDataSource"}},"id":"e9371ac2-e903-4c0c-aa97-58182fff377b","type":"DataTable"},{"attributes":{"text_color":"#FF0000"},"id":"242f433d-7ce4-4a81-be9c-0bb9145ff4e7","type":"StringFormatter"},{"attributes":{},"id":"1c18a1cc-3ec2-4b0b-bcd3-4ce3c238d8d7","type":"Strin ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[7]</strong>&gt;</code></p>
